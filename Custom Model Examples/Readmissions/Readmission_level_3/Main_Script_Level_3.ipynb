# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.impute import SimpleImputer
import joblib

from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %% [markdown]
# ### Import Data

# %%
train = pd.read_csv('../data/readmissions_train.csv')
train.drop(['diag_1_desc','diag_2_desc','diag_3_desc'],axis=1,inplace=True)

X = train.drop('readmitted',axis=1)
y = train.pop('readmitted')

# %% [markdown]
# ### Function for Keras Model

# %%
#First I define my keras model

def create_model():
    optimizer='adagrad'
    kernel_initializer='glorot_uniform'
    dropout=0.2
    
    model = Sequential()
    model.add(Dense(64,activation='relu',kernel_initializer=kernel_initializer))
    model.add(Dropout(dropout))
    model.add(Dense(1,activation='sigmoid',kernel_initializer=kernel_initializer))

    model.compile(loss='binary_crossentropy',optimizer=optimizer, metrics=['accuracy'])

    return model

# %% [markdown]
# ### Define Preprocessing step per type of column

# %%
#Preprocessing for numerical features
numeric_features = list(set(X.columns) - set(list(X.select_dtypes('object').columns)))
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

#Preprocessing for categorical features
categorical_features = list(train.select_dtypes('object').columns)
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

#Preprocessor with all of the steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %% [markdown]
# ### Fit the Preprocessing Pipeline

# %%
# Full preprocessing pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

#Train the model-Pipeline
pipeline.fit(X,y)

#Preprocess x
preprocessed = pipeline.transform(X)

# %% [markdown]
# ### Train the Keras Classifier

# %%
#Create the keras model
clf = KerasClassifier(build_fn=create_model, verbose=0)
clf.fit(preprocessed,y)

# %% [markdown]
# ### Save Custom Model files

# %%
joblib.dump(pipeline,'custom_model/preprocessing.pkl')
clf.model.save('custom_model/model.h5')

# %% [markdown]
# ### Verify custom model integrity with DRUM

# %%
# !drum validation --code-dir ./custom_model --input ../data/readmissions_test.csv --target-type binary --positive-class-label yes --negative-class-label no
# Out:
# 2020-11-30 00:34:37.577761: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:34:37.595374: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fad85b49740 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:34:37.595426: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:34:38,617 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.504705  0.495295
# 1    0.540895  0.459105
# 2    0.586829  0.413171
# 3    0.525045  0.474955
# 4    0.505892  0.494108
# ..        ...       ...
# 495  0.507780  0.492220
# 496  0.530991  0.469009
# 497  0.574898  0.425102
# 498  0.696024  0.303976
# 499  0.594062  0.405938
#
# [500 rows x 2 columns]
# 2020-11-30 00:34:43.468538: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:34:43.485359: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fc773d6b9c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:34:43.485401: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:34:44,515 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.502769  0.497231
# 1    0.534868  0.465132
# 2    0.578845  0.421155
# 3    0.509768  0.490232
# 4    0.501069  0.498931
# ..        ...       ...
# 495  0.500214  0.499786
# 496  0.518342  0.481658
# 497  0.568734  0.431266
# 498  0.683405  0.316595
# 499  0.583095  0.416905
#
# [500 rows x 2 columns]
# 2020-11-30 00:34:49.287609: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:34:49.305387: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f818f19f380 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:34:49.305449: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:34:50,320 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.496791  0.503209
# 1    0.538258  0.461742
# 2    0.581663  0.418337
# 3    0.521500  0.478500
# 4    0.497409  0.502591
# ..        ...       ...
# 495  0.500077  0.499923
# 496  0.522578  0.477422
# 497  0.570775  0.429225
# 498  0.689891  0.310109
# 499  0.587239  0.412761
#
# [500 rows x 2 columns]
# 2020-11-30 00:34:55.141725: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:34:55.157144: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f80f0196190 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:34:55.157196: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:34:56,238 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.494688  0.505312
# 1    0.537550  0.462450
# 2    0.583039  0.416961
# 3    0.521656  0.478344
# 4    0.495930  0.504070
# ..        ...       ...
# 495  0.497930  0.502070
# 496  0.521826  0.478174
# 497  0.566184  0.433816
# 498  0.692107  0.307893
# 499  0.588735  0.411265
#
# [500 rows x 2 columns]
# 2020-11-30 00:35:01.616192: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:35:01.646712: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fdb645ac530 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:35:01.646756: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:35:02,892 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.492909  0.507091
# 1    0.539500  0.460500
# 2    0.586529  0.413471
# 3    0.513287  0.486713
# 4    0.491016  0.508984
# ..        ...       ...
# 495  0.492765  0.507235
# 496  0.525568  0.474432
# 497  0.566496  0.433504
# 498  0.682026  0.317974
# 499  0.582364  0.417636
#
# [500 rows x 2 columns]
# 2020-11-30 00:35:08.509357: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:35:08.537098: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f8ba04f9f50 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:35:08.537145: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:35:09,929 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.497404  0.502596
# 1    0.542703  0.457297
# 2    0.590198  0.409802
# 3    0.513886  0.486114
# 4    0.498148  0.501852
# ..        ...       ...
# 495  0.497224  0.502776
# 496  0.517193  0.482807
# 497  0.560767  0.439233
# 498  0.685153  0.314847
# 499  0.592912  0.407088
#
# [500 rows x 2 columns]
# 2020-11-30 00:35:15.338050: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:35:15.354339: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fe71784e890 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:35:15.354375: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:35:16,379 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.491261  0.508739
# 1    0.534872  0.465128
# 2    0.584151  0.415849
# 3    0.521918  0.478082
# 4    0.499442  0.500558
# ..        ...       ...
# 495  0.502027  0.497973
# 496  0.522990  0.477010
# 497  0.570634  0.429366
# 498  0.687540  0.312460
# 499  0.588333  0.411667
#
# [500 rows x 2 columns]
# 2020-11-30 00:35:21.558587: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:35:21.575987: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fafb60f2550 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:35:21.576034: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:35:22,682 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.494320  0.505680
# 1    0.537903  0.462097
# 2    0.593317  0.406683
# 3    0.524643  0.475357
# 4    0.495044  0.504956
# ..        ...       ...
# 495  0.496677  0.503323
# 496  0.530672  0.469328
# 497  0.580652  0.419348
# 498  0.686970  0.313030
# 499  0.589941  0.410059
#
# [500 rows x 2 columns]
# 2020-11-30 00:35:28.078245: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:35:28.098583: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fa7f59df030 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:35:28.098722: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:35:29,122 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.495325  0.504675
# 1    0.545301  0.454699
# 2    0.591731  0.408269
# 3    0.530310  0.469690
# 4    0.501269  0.498731
# ..        ...       ...
# 495  0.504236  0.495764
# 496  0.521762  0.478238
# 497  0.574767  0.425233
# 498  0.691996  0.308004
# 499  0.594143  0.405857
#
# [500 rows x 2 columns]
# 2020-11-30 00:35:34.340307: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:35:34.359490: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fee4f141470 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:35:34.359535: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:35:35,331 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.499600  0.500400
# 1    0.538149  0.461851
# 2    0.586651  0.413349
# 3    0.523911  0.476089
# 4    0.493492  0.506508
# ..        ...       ...
# 495  0.497773  0.502227
# 496  0.524634  0.475366
# 497  0.574396  0.425604
# 498  0.693239  0.306761
# 499  0.590316  0.409684
#
# [500 rows x 2 columns]
# 2020-11-30 00:35:40.260874: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:35:40.276759: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fe5b86972b0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:35:40.276804: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:35:41,271 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.503029  0.496971
# 1    0.529129  0.470871
# 2    0.584462  0.415538
# 3    0.517322  0.482678
# 4    0.494127  0.505873
# ..        ...       ...
# 495  0.500449  0.499551
# 496  0.542322  0.457678
# 497  0.566222  0.433778
# 498  0.683624  0.316376
# 499  0.585216  0.414784
#
# [500 rows x 2 columns]
# 2020-11-30 00:35:46.363660: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:35:46.379430: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fcad4d40c70 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:35:46.379468: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:35:47,392 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.492283  0.507717
# 1    0.540895  0.459105
# 2    0.584462  0.415538
# 3    0.522004  0.477996
# 4    0.494917  0.505083
# ..        ...       ...
# 495  0.497018  0.502982
# 496  0.521977  0.478023
# 497  0.568601  0.431399
# 498  0.688519  0.311481
# 499  0.589663  0.410337
#
# [500 rows x 2 columns]
# 2020-11-30 00:35:52.480560: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:35:52.495763: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f894e704260 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:35:52.495808: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:35:53,454 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.490119  0.509881
# 1    0.539765  0.460235
# 2    0.592681  0.407319
# 3    0.521195  0.478805
# 4    0.494849  0.505151
# ..        ...       ...
# 495  0.496674  0.503326
# 496  0.523692  0.476308
# 497  0.566723  0.433277
# 498  0.690205  0.309795
# 499  0.588932  0.411068
#
# [500 rows x 2 columns]
# 2020-11-30 00:35:58.454561: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:35:58.470038: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fba31b2ab90 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:35:58.470077: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:35:59,533 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.494658  0.505342
# 1    0.540895  0.459105
# 2    0.584462  0.415538
# 3    0.521482  0.478518
# 4    0.494917  0.505083
# ..        ...       ...
# 495  0.497018  0.502982
# 496  0.524005  0.475995
# 497  0.566723  0.433277
# 498  0.688519  0.311481
# 499  0.587136  0.412864
#
# [500 rows x 2 columns]
# 2020-11-30 00:36:04.354664: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:36:04.368688: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f928a8d9f10 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:36:04.368722: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:36:05,209 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.494658  0.505342
# 1    0.540895  0.459105
# 2    0.584462  0.415538
# 3    0.521482  0.478518
# 4    0.494917  0.505083
# ..        ...       ...
# 495  0.497018  0.502982
# 496  0.524005  0.475995
# 497  0.566723  0.433277
# 498  0.688519  0.311481
# 499  0.587136  0.412864
#
# [500 rows x 2 columns]
# 2020-11-30 00:36:09.546875: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:36:09.563256: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f8d586f24d0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:36:09.563290: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:36:10,465 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.494658  0.505342
# 1    0.540895  0.459105
# 2    0.518532  0.481468
# 3    0.521482  0.478518
# 4    0.494917  0.505083
# ..        ...       ...
# 495  0.497018  0.502982
# 496  0.524005  0.475995
# 497  0.500617  0.499383
# 498  0.531206  0.468794
# 499  0.523336  0.476664
#
# [500 rows x 2 columns]
# 2020-11-30 00:36:14.897072: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:36:14.912125: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fa9b53311c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:36:14.912165: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:36:15,816 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.500159  0.499841
# 1    0.540213  0.459787
# 2    0.585301  0.414699
# 3    0.527106  0.472894
# 4    0.495322  0.504678
# ..        ...       ...
# 495  0.499302  0.500698
# 496  0.522667  0.477333
# 497  0.565097  0.434903
# 498  0.688005  0.311995
# 499  0.581948  0.418052
#
# [500 rows x 2 columns]
# 2020-11-30 00:36:20.232782: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:36:20.248070: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fcf4063bc50 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:36:20.248107: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:36:21,134 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.496278  0.503722
# 1    0.541507  0.458493
# 2    0.588589  0.411411
# 3    0.519082  0.480918
# 4    0.495923  0.504077
# ..        ...       ...
# 495  0.495990  0.504010
# 496  0.523731  0.476269
# 497  0.570485  0.429515
# 498  0.686967  0.313033
# 499  0.583569  0.416431
#
# [500 rows x 2 columns]
# 2020-11-30 00:36:25.683070: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:36:25.699033: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f8dd9576cf0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:36:25.699072: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:36:26,574 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.492415  0.507585
# 1    0.538968  0.461032
# 2    0.580654  0.419346
# 3    0.519897  0.480103
# 4    0.497777  0.502223
# ..        ...       ...
# 495  0.503785  0.496215
# 496  0.524005  0.475995
# 497  0.563397  0.436603
# 498  0.691891  0.308109
# 499  0.587621  0.412379
#
# [500 rows x 2 columns]
# 2020-11-30 00:36:30.891781: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:36:30.905966: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f856a6a8810 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:36:30.906002: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:36:31,762 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.494804  0.505196
# 1    0.540421  0.459579
# 2    0.584683  0.415317
# 3    0.519181  0.480819
# 4    0.494892  0.505108
# ..        ...       ...
# 495  0.497018  0.502982
# 496  0.525484  0.474516
# 497  0.566398  0.433602
# 498  0.692258  0.307742
# 499  0.587368  0.412632
#
# [500 rows x 2 columns]
# 2020-11-30 00:36:36.050163: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:36:36.063598: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fd08440fe40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:36:36.063632: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:36:36,882 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.501348  0.498652
# 1    0.545512  0.454488
# 2    0.591535  0.408465
# 3    0.525536  0.474464
# 4    0.499439  0.500561
# ..        ...       ...
# 495  0.502728  0.497272
# 496  0.532838  0.467162
# 497  0.572162  0.427838
# 498  0.693042  0.306958
# 499  0.596463  0.403537
#
# [500 rows x 2 columns]
# 2020-11-30 00:36:41.057379: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:36:41.070962: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f8b681e2270 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:36:41.070997: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:36:41,892 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.490310  0.509690
# 1    0.544529  0.455471
# 2    0.586078  0.413922
# 3    0.519134  0.480866
# 4    0.490624  0.509376
# ..        ...       ...
# 495  0.497872  0.502128
# 496  0.530561  0.469439
# 497  0.566129  0.433871
# 498  0.689985  0.310015
# 499  0.588543  0.411457
#
# [500 rows x 2 columns]
# 2020-11-30 00:36:46.079693: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:36:46.097439: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fcde815c8f0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:36:46.097479: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:36:46,920 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.494934  0.505066
# 1    0.538647  0.461353
# 2    0.583648  0.416352
# 3    0.518441  0.481559
# 4    0.502457  0.497543
# ..        ...       ...
# 495  0.495357  0.504643
# 496  0.528720  0.471280
# 497  0.563541  0.436459
# 498  0.685154  0.314846
# 499  0.587156  0.412844
#
# [500 rows x 2 columns]
# 2020-11-30 00:36:51.742249: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:36:51.758737: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fcd0aa64370 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:36:51.758781: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:36:52,853 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.493315  0.506685
# 1    0.542656  0.457344
# 2    0.584677  0.415323
# 3    0.517198  0.482802
# 4    0.495265  0.504735
# ..        ...       ...
# 495  0.497495  0.502505
# 496  0.522928  0.477072
# 497  0.563901  0.436099
# 498  0.693097  0.306903
# 499  0.588009  0.411991
#
# [500 rows x 2 columns]
# 2020-11-30 00:36:58.216195: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:36:58.233243: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ff1dc7208a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:36:58.233282: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:36:59,167 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.490166  0.509834
# 1    0.533697  0.466303
# 2    0.576802  0.423198
# 3    0.519231  0.480769
# 4    0.488606  0.511394
# ..        ...       ...
# 495  0.493212  0.506788
# 496  0.521100  0.478900
# 497  0.563858  0.436142
# 498  0.682404  0.317596
# 499  0.583163  0.416837
#
# [500 rows x 2 columns]
# 2020-11-30 00:37:04.308692: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-11-30 00:37:04.324500: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f98397b0520 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-30 00:37:04.324558: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# /Users/thodoris.petropoulos/opt/anaconda3/envs/readmissions_custom/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 2020-11-30 00:37:05,663 WARNING tensorflow:  From /Users/thodoris.petropoulos/github/mlops-examples-wip/Custom Model Examples/Readmissions/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.496271  0.503729
# 1    0.539314  0.460686
# 2    0.583028  0.416972
# 3    0.519531  0.480469
# 4    0.495293  0.504707
# ..        ...       ...
# 495  0.498841  0.501159
# 496  0.520764  0.479236
# 497  0.564995  0.435005
# 498  0.688261  0.311739
# 499  0.588060  0.411940
#
# [500 rows x 2 columns]
