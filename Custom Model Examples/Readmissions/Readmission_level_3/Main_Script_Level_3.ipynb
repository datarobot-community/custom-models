# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.impute import SimpleImputer
import joblib

from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %% [markdown]
# ### Import Data

# %%
train = pd.read_csv('../data/readmissions_train.csv')
train.drop(['diag_1_desc','diag_2_desc','diag_3_desc'],axis=1,inplace=True)

X = train.drop('readmitted',axis=1)
y = train.pop('readmitted')

# %% [markdown]
# ### Function for Keras Model

# %%
#First I define my keras model

def create_model():
    optimizer='adagrad'
    kernel_initializer='glorot_uniform'
    dropout=0.2
    
    model = Sequential()
    model.add(Dense(64,activation='relu',kernel_initializer=kernel_initializer))
    model.add(Dropout(dropout))
    model.add(Dense(1,activation='sigmoid',kernel_initializer=kernel_initializer))

    model.compile(loss='binary_crossentropy',optimizer=optimizer, metrics=['accuracy'])

    return model

# %% [markdown]
# ### Define Preprocessing step per type of column

# %%
#Preprocessing for numerical features
numeric_features = list(set(X.columns) - set(list(X.select_dtypes('object').columns)))
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

#Preprocessing for categorical features
categorical_features = list(train.select_dtypes('object').columns)
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

#Preprocessor with all of the steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %% [markdown]
# ### Fit the Preprocessing Pipeline

# %%
# Full preprocessing pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

#Train the model-Pipeline
pipeline.fit(X,y)

#Preprocess x
preprocessed = pipeline.transform(X)

#I could also train the model with the sparse matrix. I transform it to padnas because the hook function in custom.py expected a pandas dataframe to be used for scoring.
preprocessed = pd.DataFrame.sparse.from_spmatrix(preprocessed)

# %% [markdown]
# ### Train the Keras Classifier

# %%
#Create the keras model
clf = KerasClassifier(build_fn=create_model, verbose=0)
clf.fit(preprocessed,y)
# Out:
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.

# %% [markdown]
# ### Save Custom Model files

# %%
joblib.dump(pipeline,'custom_model/preprocessing.pkl')
clf.model.save('custom_model/model.h5')

# %% [markdown]
# ### Verify custom model integrity with DRUM

# %%
# !drum validation --code-dir ./custom_model --input ../data/readmissions_test.csv --target-type binary --positive-class-label yes --negative-class-label no
# Out:
# service.cc:176]   StreamExecutor device (0): Host, Default Version
#           yes        no
# 0    0.493643  0.506357
# 1    0.518077  0.481923
# 2    0.587562  0.412438
# 3    0.528309  0.471691
# 4    0.485512  0.514488
# ..        ...       ...
# 495  0.504027  0.495973
# 496  0.524551  0.475449
# 497  0.579017  0.420983
# 498  0.644561  0.355439
# 499  0.602131  0.397869
#
# [500 rows x 2 columns]
# 2020-12-01 15:36:05.327622: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-01 15:36:05.343361: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7feedbf64520 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-01 15:36:05.343402: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#           yes        no
# 0    0.500467  0.499533
# 1    0.516444  0.483556
# 2    0.590500  0.409500
# 3    0.528054  0.471946
# 4    0.483209  0.516791
# ..        ...       ...
# 495  0.506337  0.493663
# 496  0.531183  0.468817
# 497  0.578290  0.421710
# 498  0.651507  0.348493
# 499  0.606633  0.393367
#
# [500 rows x 2 columns]
# 2020-12-01 15:36:10.195680: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-01 15:36:10.210027: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f9a15ea2f30 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-01 15:36:10.210062: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#           yes        no
# 0    0.499123  0.500877
# 1    0.521790  0.478210
# 2    0.594054  0.405946
# 3    0.532632  0.467368
# 4    0.493325  0.506675
# ..        ...       ...
# 495  0.509441  0.490559
# 496  0.529026  0.470974
# 497  0.585374  0.414626
# 498  0.651093  0.348907
# 499  0.609026  0.390974
#
# [500 rows x 2 columns]
# 2020-12-01 15:36:15.139973: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-01 15:36:15.154489: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f902d05a150 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-01 15:36:15.154530: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#           yes        no
# 0    0.489986  0.510014
# 1    0.510599  0.489401
# 2    0.584645  0.415355
# 3    0.524967  0.475033
# 4    0.480614  0.519386
# ..        ...       ...
# 495  0.500970  0.499030
# 496  0.519515  0.480485
# 497  0.580265  0.419735
# 498  0.641911  0.358089
# 499  0.601391  0.398609
#
# [500 rows x 2 columns]
# 2020-12-01 15:36:19.981386: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-01 15:36:19.997278: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fa594fcb6c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-01 15:36:19.997339: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#           yes        no
# 0    0
I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#           yes        no
# 0    0.491600  0.508400
# 1    0.513673  0.486327
# 2    0.589947  0.410053
# 3    0.527317  0.472683
# 4    0.482419  0.517581
# ..        ...       ...
# 495  0.503656  0.496344
# 496  0.521460  0.478540
# 497  0.578354  0.421646
# 498  0.646497  0.353503
# 499  0.600807  0.399193
#
# [500 rows x 2 columns]
# 2020-12-01 15:37:08.429158: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-01 15:37:08.444578: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f854d473770 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-01 15:37:08.444635: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#           yes        no
# 0    0.494480  0.505520
# 1    0.520390  0.479610
# 2    0.590973  0.409027
# 3    0.525887  0.474113
# 4    0.487071  0.512929
# ..        ...       ...
# 495  0.506410  0.493590
# 496  0.529850  0.470150
# 497  0.574228  0.425772
# 498  0.646723  0.353277
# 499  0.604915  0.395085
#
# [500 rows x 2 columns]
# 2020-12-01 15:37:13.267879: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-01 15:37:13.283679: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fb50660e560 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-01 15:37:13.283713: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#           yes        no
# 0    0.491508  0.508492
# 1    0.516461  0.483539
# 2    0.592346  0.407654
# 3    0.532207  0.467793
# 4    0.487492  0.512508
# ..        ...       ...
# 495  0.507251  0.492749
# 496  0.529409  0.470591
# 497  0.576861  0.423139
# 498  0.648202  0.351798
# 499  0.603336  0.396664
#
# [500 rows x 2 columns]
# 2020-12-01 15:37:18.154787: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-01 15:37:18.168263: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f9fedec1410 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-01 15:37:18.168299: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#           yes        no
# 0    0.504483  0.495517
# 1    0.527537  0.472463
# 2    0.595599  0.404401
# 3    0.534901  0.465099
# 4    0.497602  0.502398
# ..        ...       ...
# 495  0.516956  0.483044
# 496  0.535265  0.464735
# 497  0.584283  0.415717
# 498  0.654945  0.345055
# 499  0.609854  0.390146
#
# [500 rows x 2 columns]
# 2020-12-01 15:37:22.999529: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-01 15:37:23.014858: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ffbfb80cc60 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-01 15:37:23.014899: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#           yes        no
# 0    0.496230  0.503770
# 1    0.520693  0.479307
# 2    0.593400  0.406600
# 3    0.532005  0.467995
# 4    0.489468  0.510532
# ..        ...       ...
# 495  0.509191  0.490809
# 496  0.528845  0.471155
# 497  0.581005  0.418995
# 498  0.650980  0.349020
# 499  0.612502  0.387498
#
# [500 rows x 2 columns]
# 2020-12-01 15:37:27.873970: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-01 15:37:27.888764: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fde7af25710 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-01 15:37:27.888799: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#           yes        no
# 0    0.490765  0.509235
# 1    0.516793  0.483207
# 2    0.586621  0.413379
# 3    0.529997  0.470003
# 4    0.483130  0.516870
# ..        ...       ...
# 495  0.505586  0.494414
# 496  0.528517  0.471483
# 497  0.582846  0.417154
# 498  0.642893  0.357107
# 499  0.599453  0.400547
#
# [500 rows x 2 columns]
# 2020-12-01 15:37:32.707508: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-01 15:37:32.721775: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f92c4b73d70 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-01 15:37:32.721817: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#           yes        no
# 0    0.496019  0.503981
# 1    0.517818  0.482182
# 2    0.589421  0.410579
# 3    0.529449  0.470551
# 4    0.485595  0.514405
# ..        ...       ...
# 495  0.505621  0.494379
# 496  0.530295  0.469705
# 497  0.576095  0.423905
# 498  0.642462  0.357538
# 499  0.598796  0.401204
#
# [500 rows x 2 columns]
# 2020-12-01 15:37:37.563308: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-01 15:37:37.577540: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ff8d1f7ee00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-01 15:37:37.577574: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#           yes        no
# 0    0.492893  0.507107
# 1    0.516466  0.483534
# 2    0.589684  0.410316
# 3    0.526765  0.473235
# 4    0.484338  0.515662
# ..        ...       ...
# 495  0.504787  0.495213
# 496  0.526223  0.473777
# 497  0.577874  0.422126
# 498  0.646466  0.353534
# 499  0.603817  0.396183
#
# [500 rows x 2 columns]
#
#
# Validation checks results
#       Test case         Status
# ==============================
# Null value imputation   PASSED
