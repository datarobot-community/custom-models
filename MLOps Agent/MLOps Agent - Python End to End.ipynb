# %% [markdown]
# ## MLOps Agent - Python End to End
# **Author**: Matthew Cohen
#
# #### Scope
# The scope of this Notebook is to provide instructions on how to use DataRobot's MLOps Agents.
#
# #### Requirements
#
# - Python 3.7.3
# - MLOps Agent 6.1.3
#
# Your version might be different but the below procedure should remain the same.

# %% [markdown]
# ### Installing the Agent
#
# In DataRobot, navigate to your deployment of the external model:
# - Click on the Deployment itself.
# - Then click on "Integrations and follow the instructions you see for your selected language (Python, Java, R).
# - You will need to install the MLOPs Library. In python this is done with:
#   - pip install <unpacked DataRobot's Monitoring Agent tar file>/lib/datarobot_mlops-*-py2.py3-none-any.whl
#
#
# Usage:
#     DataRobot's Monitoring Agent is an advanced feature that enables monitoring for models deployed
#     outside of DataRobot. Follow these steps to use this feature.
#     1. Download and extract DataRobot's Monitoring Agent tar file. This is available through the
#        DataRobot MLOps UI via User icon -> "Developer Tools" -> "External Monitoring Agent".
#     2. Open your preferred browser. In toolbar, click "File" -> "Open File".
#        Then choose this file <your unpacked directory>/docs/html/quickstart.html.
#     3. Follow the "Quick Start" instructions to set up Monitoring Agent.
#     4. This example uses the DataRobot's MLOps library which you can install with:
#        pip install <unpacked DataRobot's Monitoring Agent tar file>/lib/datarobot_mlops-*-py2.py3-none-any.whl
#     5. MLOps library requires the following parameters to be provided:
#        deployment ID, model ID, output type [STDOUT, OUTPUT_DIR, NULL].
#        If output type is OUTPUT_DIR, which means that Monitoring Agent will send data to the DataRobot MLOPs service,
#        the following parameters also have to be configured: spool directory, max size per spool file,
#        max number of spool files. Spool directory path must match the Monitoring Agent path configured by admin.
#        For advanced usage, see the examples.
#        These parameters can be configured with APIs, check the MLOps library init() call,
#        or with environment variables. For example:
#        # export MLOPS_DEPLOYMENT_ID='YOUR_DEPLOYMENT_ID'
#        # export MLOPS_MODEL_ID='YOUR_DEPLOYMENT_ID'
#        # export MLOPS_OUTPUT_TYPE=OUTPUT_DIR
#        # export MLOPS_SPOOLER_DIR_PATH=/tmp/ta
#        # export MLOPS_SPOOLER_FILE_MAX_SIZE=104857600
#        # export MLOPS_SPOOLER_MAX_FILES=5
#
#        Notes:
#               - parameter configuration via the API takes precedence over environment variables.
#               - for testing purposes, you can start with STDOUT output type,
#                 which doesn't require providing any of the spooler-related parameters.
#     6. Run current snippet:
#        python datarobot-report-stats.py

# %% [markdown]
# #### Once it is downloaded....
# and saved to your local filesystem, open/uncompress the file

# %%
#
# Change directory to where you saved the tar file and uncompressed it
#  .../{agent install dir}
#
# %cd ~/Documents/DR/MLOps/_Agent_example
# !tar -xvf datarobot-mlops-agent-6.2.1-363.tar.gz
# %cd ./datarobot-mlops-agent-6.2.1
# Out:
# /Users/matthew.cohen/Documents/DR/MLOps/_Agent_example
# x datarobot-mlops-agent-6.2.1/
# x datarobot-mlops-agent-6.2.1/bin/
# x datarobot-mlops-agent-6.2.1/bin/stop-bosun.sh
# x datarobot-mlops-agent-6.2.1/bin/start-bosun.sh
# x datarobot-mlops-agent-6.2.1/bin/start-agent.sh
# x datarobot-mlops-agent-6.2.1/bin/status-agent.sh
# x datarobot-mlops-agent-6.2.1/bin/run-agent-once.sh
# x datarobot-mlops-agent-6.2.1/bin/stop-agent.sh
# x datarobot-mlops-agent-6.2.1/bin/status-bosun.sh
# x datarobot-mlops-agent-6.2.1/logs/
# x datarobot-mlops-agent-6.2.1/logs/mlops.agent.log
# x datarobot-mlops-agent-6.2.1/logs/mlops.bosun.log
# x datarobot-mlops-agent-6.2.1/bosun_plugins/
# x datarobot-mlops-agent-6.2.1/bosun_plugins/mlops-bosun-plugin-externalcommand-6.2.1.jar
# x datarobot-mlops-agent-6.2.1/.BUILD.info
# x datarobot-mlops-agent-6.2.1/README.md
# x datarobot-mlops-agent-6.2.1/conf/
# x datarobot-mlops-agent-6.2.1/conf/stdout.mlops.log4j2.properties
# x datarobot-mlops-agent-6.2.1/conf/mlops.log4j2.properties
# x datarobot-mlops-agent-6.2.1/conf/mlops.bosun.log4j2.properties
# x datarobot-mlops-agent-6.2.1/conf/mlops.bosun.conf.yaml
# x datarobot-mlops-agent-6.2.1/conf/template-conf.yaml
# x datarobot-mlops-agent-6.2.1/conf/mlops.agent.conf.yaml
# x datarobot-mlops-agent-6.2.1/tools/
# x datarobot-mlops-agent-6.2.1/tools/upload_actuals.py
# x datarobot-mlops-agent-6.2.1/tools/csv_modifier.py
# x datarobot-mlops-agent-6.2.1/tools/mlops_client.py
# x datarobot-mlops-agent-6.2.1/tools/k8s-installer/
# x datarobot-mlops-agent-6.2.1/tools/k8s-installer/prediction-k8s.yaml
# x datarobot-mlops-agent-6.2.1/tools/k8s-installer/README.md
# x datarobot-mlops-agent-6.2.1/tools/k8s-installer/run-pps.sh
# x datarobot-mlops-agent-6.2.1/tools/k8s-installer/pps-deployment.yaml
# x datarobot-mlops-agent-6.2.1/tools/tools-java/
# x datarobot-mlops-agent-6.2.1/tools/tools-java/pom.xml
# x datarobot-mlops-agent-6.2.1/tools/tools-java/src/
# x datarobot-mlops-agent-6.2.1/tools/tools-java/src/main/
# x datarobot-mlops-agent-6.2.1/tools/tools-java/src/main/java/
# x datarobot-mlops-agent-6.2.1/tools/tools-java/src/main/java/com/
# x datarobot-mlops-agent-6.2.1/tools/tools-java/src/main/java/com/datarobot/
# x datarobot-mlops-agent-6.2.1/tools/tools-java/src/main/java/com/datarobot/mlops/
# x datarobot-mlops-agent-6.2.1/tools/tools-java/src/main/java/com/datarobot/mlops/tools/
# x datarobot-mlops-agent-6.2.1/tools/tools-java/src/main/java/com/datarobot/mlops/tools/GetCodeGenModelId.java
# x datarobot-mlops-agent-6.2.1/tools/tools-java/run_get_codegen_modelid.sh
# x datarobot-mlops-agent-6.2.1/tools/tools-java/Makefile
# x datarobot-mlops-agent-6.2.1/examples/
# x datarobot-mlops-agent-6.2.1/examples/java/
# x datarobot-mlops-agent-6.2.1/examples/java/install_jar_into_maven.sh
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/pom.xml
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/src/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/src/main/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/src/main/resources/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/src/main/resources/log4j2.xml
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/src/main/scala/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/src/main/scala/com/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/src/main/scala/com/datarobot/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/src/main/scala/com/datarobot/dr_mlops_spark/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/src/main/scala/com/datarobot/dr_mlops_spark/Main.scala
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/run_example.sh
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/README.md
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/create_deployment.sh
# x datarobot-mlops-agent-6.2.1/examples/java/SparkUtilsExample/Makefile
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/pom.xml
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/src/
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/src/main/
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/src/main/java/
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/src/main/java/com/
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/src/main/java/com/datarobot/
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/src/main/java/com/datarobot/mlops/
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/src/main/java/com/datarobot/mlops/examples/
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/src/main/java/com/datarobot/mlops/examples/PredictionsData.java
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/src/main/resources/
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/src/main/resources/log4j2.xml
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/upload_actuals.sh
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/run_example.sh
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/README.md
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/create_deployment.sh
# x datarobot-mlops-agent-6.2.1/examples/java/PredictionsData/Makefile
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/pom.xml
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/src/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/src/main/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/src/main/resources/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/src/main/resources/log4j2.xml
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/src/main/scala/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/src/main/scala/com/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/src/main/scala/com/datarobot/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/src/main/scala/com/datarobot/dr_mloa_spark/
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/src/main/scala/com/datarobot/dr_mloa_spark/Main.scala
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/run_example.sh
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/README.md
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/create_deployment.sh
# x datarobot-mlops-agent-6.2.1/examples/java/SparkExample/Makefile
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/pom.xml
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/src/
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/src/main/
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/src/main/java/
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/src/main/java/com/
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/src/main/java/com/datarobot/
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/src/main/java/com/datarobot/mlops/
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/src/main/java/com/datarobot/mlops/examples/
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/src/main/java/com/datarobot/mlops/examples/MLOpsCodeGenRegressionApp.java
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/src/main/java/com/datarobot/mlops/examples/controller/
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/src/main/java/com/datarobot/mlops/examples/controller/PredictController.java
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/src/main/resources/
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/src/main/resources/log4j2.xml
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/src/main/resources/application.properties
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/Dockerfile
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/kubernetes-deployment.yaml
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/VERSION
# x datarobot-mlops-agent-6.2.1/examples/java/RegressionCodeGenWebSample/Makefile
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/pom.xml
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/src/
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/src/main/
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/src/main/java/
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/src/main/java/com/
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/src/main/java/com/datarobot/
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/src/main/java/com/datarobot/mlops/
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/src/main/java/com/datarobot/mlops/examples/
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/src/main/java/com/datarobot/mlops/examples/SingleCommandExample.java
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/src/main/resources/
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/src/main/resources/log4j2.xml
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/run_example.sh
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/README.md
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/config.sh
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/create_deployment.sh
# x datarobot-mlops-agent-6.2.1/examples/java/SingleCommandExample/Makefile
# x datarobot-mlops-agent-6.2.1/examples/java/README
# x datarobot-mlops-agent-6.2.1/examples/java/SampleCode/
# x datarobot-mlops-agent-6.2.1/examples/java/SampleCode/pom.xml
# x datarobot-mlops-agent-6.2.1/examples/java/SampleCode/src/
# x datarobot-mlops-agent-6.2.1/examples/java/SampleCode/src/main/
# x datarobot-mlops-agent-6.2.1/examples/java/SampleCode/src/main/java/
# x datarobot-mlops-agent-6.2.1/examples/java/SampleCode/src/main/java/com/
# x datarobot-mlops-agent-6.2.1/examples/java/SampleCode/src/main/java/com/datarobot/
# x datarobot-mlops-agent-6.2.1/examples/java/SampleCode/src/main/java/com/datarobot/mlops/
# x datarobot-mlops-agent-6.2.1/examples/java/SampleCode/src/main/java/com/datarobot/mlops/examples/
# x datarobot-mlops-agent-6.2.1/examples/java/SampleCode/src/main/java/com/datarobot/mlops/examples/RegressionSampleCode.java
# x datarobot-mlops-agent-6.2.1/examples/java/SampleCode/README.md
# x datarobot-mlops-agent-6.2.1/examples/java/SampleCode/Makefile
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/pom.xml
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/src/
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/src/main/
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/src/main/java/
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/src/main/java/com/
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/src/main/java/com/datarobot/
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/src/main/java/com/datarobot/mlops/
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/src/main/java/com/datarobot/mlops/examples/
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/src/main/java/com/datarobot/mlops/examples/CodeGenExample.java
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/src/main/resources/
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/src/main/resources/log4j2.xml
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/run_example.sh
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/README.md
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/create_deployment.sh
# x datarobot-mlops-agent-6.2.1/examples/java/CodeGenExample/Makefile
# x datarobot-mlops-agent-6.2.1/examples/java/Makefile
# x datarobot-mlops-agent-6.2.1/examples/python/
# x datarobot-mlops-agent-6.2.1/examples/python/PySparkExample/
# x datarobot-mlops-agent-6.2.1/examples/python/PySparkExample/run_example.sh
# x datarobot-mlops-agent-6.2.1/examples/python/PySparkExample/README.md
# x datarobot-mlops-agent-6.2.1/examples/python/PySparkExample/create_deployment.sh
# x datarobot-mlops-agent-6.2.1/examples/python/PySparkExample/pyspark_random_forest.py
# x datarobot-mlops-agent-6.2.1/examples/python/README.md
# x datarobot-mlops-agent-6.2.1/examples/python/SingleCommandExample/
# x datarobot-mlops-agent-6.2.1/examples/python/SingleCommandExample/mlops_example.py
# x datarobot-mlops-agent-6.2.1/examples/python/SingleCommandExample/run_example.sh
# x datarobot-mlops-agent-6.2.1/examples/python/SingleCommandExample/README.md
# x datarobot-mlops-agent-6.2.1/examples/python/SingleCommandExample/config.sh
# x datarobot-mlops-agent-6.2.1/examples/python/SingleCommandExample/create_deployment.sh
# x datarobot-mlops-agent-6.2.1/examples/python/BinaryClassificationExample/
# x datarobot-mlops-agent-6.2.1/examples/python/BinaryClassificationExample/upload_actuals.sh
# x datarobot-mlops-agent-6.2.1/examples/python/BinaryClassificationExample/run_example.sh
# x datarobot-mlops-agent-6.2.1/examples/python/BinaryClassificationExample/README.md
# x datarobot-mlops-agent-6.2.1/examples/python/BinaryClassificationExample/binary_classification.py
# x datarobot-mlops-agent-6.2.1/examples/python/BinaryClassificationExample/create_deployment.sh
# x datarobot-mlops-agent-6.2.1/examples/python/requirements.txt
# x datarobot-mlops-agent-6.2.1/examples/python/SampleCode/
# x datarobot-mlops-agent-6.2.1/examples/python/SampleCode/regression_sample_code.py
# x datarobot-mlops-agent-6.2.1/examples/python/SampleCode/actuals_demo.py
# x datarobot-mlops-agent-6.2.1/examples/examples_config_helper.sh
# x datarobot-mlops-agent-6.2.1/examples/r/
# x datarobot-mlops-agent-6.2.1/examples/r/PredictionsDataExample/
# x datarobot-mlops-agent-6.2.1/examples/r/PredictionsDataExample/upload_actuals.sh
# x datarobot-mlops-agent-6.2.1/examples/r/PredictionsDataExample/run_example.sh
# x datarobot-mlops-agent-6.2.1/examples/r/PredictionsDataExample/predictions_data.r
# x datarobot-mlops-agent-6.2.1/examples/r/PredictionsDataExample/create_deployment.sh
# x datarobot-mlops-agent-6.2.1/examples/r/README
# x datarobot-mlops-agent-6.2.1/examples/r/ClassificationExample/
# x datarobot-mlops-agent-6.2.1/examples/r/ClassificationExample/run_example.sh
# x datarobot-mlops-agent-6.2.1/examples/r/ClassificationExample/classification_example.r
# x datarobot-mlops-agent-6.2.1/examples/r/ClassificationExample/create_deployment.sh
# x datarobot-mlops-agent-6.2.1/examples/r/RegressionExample/
# x datarobot-mlops-agent-6.2.1/examples/r/RegressionExample/regression_example.r
# x datarobot-mlops-agent-6.2.1/examples/r/RegressionExample/run_example.sh
# x datarobot-mlops-agent-6.2.1/examples/r/RegressionExample/create_deployment.sh
# x datarobot-mlops-agent-6.2.1/examples/model_config/
# x datarobot-mlops-agent-6.2.1/examples/model_config/lending_club_regression.json
# x datarobot-mlops-agent-6.2.1/examples/model_config/iris_multi_classification.json
# x datarobot-mlops-agent-6.2.1/examples/model_config/surgical_binary_classification.json
# x datarobot-mlops-agent-6.2.1/examples/models/
# x datarobot-mlops-agent-6.2.1/examples/models/CodeGenLendingClubRegressor.jar
# x datarobot-mlops-agent-6.2.1/examples/data/
# x datarobot-mlops-agent-6.2.1/examples/data/short-lending-club-regression.csv
# x datarobot-mlops-agent-6.2.1/examples/data/iris-samples.csv
# x datarobot-mlops-agent-6.2.1/examples/data/surgical-dataset.csv
# x datarobot-mlops-agent-6.2.1/examples/data/lending-club-regression.csv
# x datarobot-mlops-agent-6.2.1/examples/data/very-short-lending-club-regression.csv
# x datarobot-mlops-agent-6.2.1/examples/README
# x datarobot-mlops-agent-6.2.1/examples/Makefile
# x datarobot-mlops-agent-6.2.1/LICENSE.txt
# x datarobot-mlops-agent-6.2.1/lib/
# x datarobot-mlops-agent-6.2.1/lib/datarobot.mlops_6.2.1-r.tar.gz
# x datarobot-mlops-agent-6.2.1/lib/datarobot-mlops-6.2.1.jar
# x datarobot-mlops-agent-6.2.1/lib/datarobot_mlops-6.2.1-py2.py3-none-any.whl
# x datarobot-mlops-agent-6.2.1/lib/mlops-agent-6.2.1.jar
# x datarobot-mlops-agent-6.2.1/docs/
# x datarobot-mlops-agent-6.2.1/docs/html/
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/agent_configuration.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/mlops_python.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/index.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/java_api.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/mlops_java.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/agent_installation.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/overview.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/r_installation.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/java_installation.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/release_notes.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/r_examples.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/python_installation.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/quickstart.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/python_examples.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/python_api.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/spark_monitoring_use_case.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/mlops_client.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/java_examples.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/java_spark_api.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/agent.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/r_api.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/create_deployment.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/mlops_lib.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/mlops_r.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/examples.doctree
# x datarobot-mlops-agent-6.2.1/docs/html/.doctrees/environment.pickle
# x datarobot-mlops-agent-6.2.1/docs/html/r_installation.html
# x datarobot-mlops-agent-6.2.1/docs/html/java_spark_api.html
# x datarobot-mlops-agent-6.2.1/docs/html/overview.html
# x datarobot-mlops-agent-6.2.1/docs/html/r_api.html
# x datarobot-mlops-agent-6.2.1/docs/html/genindex.html
# x datarobot-mlops-agent-6.2.1/docs/html/objects.inv
# x datarobot-mlops-agent-6.2.1/docs/html/mlops_python.html
# x datarobot-mlops-agent-6.2.1/docs/html/searchindex.js
# x datarobot-mlops-agent-6.2.1/docs/html/quickstart.html
# x datarobot-mlops-agent-6.2.1/docs/html/python_examples.html
# x datarobot-mlops-agent-6.2.1/docs/html/python_api.html
# x datarobot-mlops-agent-6.2.1/docs/html/agent_configuration.html
# x datarobot-mlops-agent-6.2.1/docs/html/java_examples.html
# x datarobot-mlops-agent-6.2.1/docs/html/r_examples.html
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/mlops_client.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/python_examples.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/agent.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/r_api.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/create_deployment.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/r_installation.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/quickstart.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/java_installation.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/mlops_java.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/python_installation.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/agent_configuration.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/java_api.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/mlops_r.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/examples.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/mlops_lib.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/release_notes.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/spark_monitoring_use_case.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/agent_installation.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/java_examples.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/java_spark_api.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/index.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/python_api.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/r_examples.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/mlops_python.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_sources/overview.rst.txt
# x datarobot-mlops-agent-6.2.1/docs/html/_static/
# x datarobot-mlops-agent-6.2.1/docs/html/_static/minus.png
# x datarobot-mlops-agent-6.2.1/docs/html/_static/pygments.css
# x datarobot-mlops-agent-6.2.1/docs/html/_static/comment-close.png
# x datarobot-mlops-agent-6.2.1/docs/html/_static/doctools.js
# x datarobot-mlops-agent-6.2.1/docs/html/_static/up.png
# x datarobot-mlops-agent-6.2.1/docs/html/_static/down-pressed.png
# x datarobot-mlops-agent-6.2.1/docs/html/_static/basic.css
# x datarobot-mlops-agent-6.2.1/docs/html/_static/jquery-3.2.1.js
# x datarobot-mlops-agent-6.2.1/docs/html/_static/down.png
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Roboto-Slab-Light.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-italic.eot
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-regular.ttf
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-regular.eot
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-bold.eot
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-bold.ttf
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-bolditalic.eot
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-italic.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-bolditalic.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-bold.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-bold.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-bolditalic.ttf
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-regular.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-italic.ttf
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-italic.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-bolditalic.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Lato/lato-regular.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/fontawesome-webfont.svg
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/fontawesome-webfont.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/RobotoSlab/
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/RobotoSlab/roboto-slab-v7-bold.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/RobotoSlab/roboto-slab-v7-regular.eot
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/RobotoSlab/roboto-slab-v7-bold.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/RobotoSlab/roboto-slab-v7-bold.ttf
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/RobotoSlab/roboto-slab-v7-regular.ttf
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/RobotoSlab/roboto-slab-v7-bold.eot
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/RobotoSlab/roboto-slab-v7-regular.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/RobotoSlab/roboto-slab-v7-regular.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Roboto-Slab-Thin.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/lato-normal.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/FontAwesome.otf
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/lato-normal-italic.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/lato-bold-italic.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/fontawesome-webfont.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/lato-normal.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Roboto-Slab-Thin.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/fontawesome-webfont.ttf
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Roboto-Slab-Bold.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/lato-bold-italic.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/lato-normal-italic.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Roboto-Slab-Regular.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/lato-bold.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/lato-bold.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Roboto-Slab-Bold.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Roboto-Slab-Regular.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/fontawesome-webfont.eot
# x datarobot-mlops-agent-6.2.1/docs/html/_static/fonts/Roboto-Slab-Light.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/theme.css
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/badge_only.css
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/fontawesome-webfont.svg
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/fontawesome-webfont.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/lato-normal.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/lato-normal-italic.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/lato-bold-italic.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/fontawesome-webfont.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/lato-normal.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/fontawesome-webfont.ttf
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/Roboto-Slab-Bold.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/lato-bold-italic.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/lato-normal-italic.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/Roboto-Slab-Regular.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/lato-bold.woff
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/lato-bold.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/Roboto-Slab-Bold.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/Roboto-Slab-Regular.woff2
# x datarobot-mlops-agent-6.2.1/docs/html/_static/css/fonts/fontawesome-webfont.eot
# x datarobot-mlops-agent-6.2.1/docs/html/_static/up-pressed.png
# x datarobot-mlops-agent-6.2.1/docs/html/_static/plus.png
# x datarobot-mlops-agent-6.2.1/docs/html/_static/file.png
# x datarobot-mlops-agent-6.2.1/docs/html/_static/js/
# x datarobot-mlops-agent-6.2.1/docs/html/_static/js/html5shiv.min.js
# x datarobot-mlops-agent-6.2.1/docs/html/_static/js/modernizr.min.js
# x datarobot-mlops-agent-6.2.1/docs/html/_static/js/theme.js
# x datarobot-mlops-agent-6.2.1/docs/html/_static/js/html5shiv-printshiv.min.js
# x datarobot-mlops-agent-6.2.1/docs/html/_static/js/badge_only.js
# x datarobot-mlops-agent-6.2.1/docs/html/_static/searchtools.js
# x datarobot-mlops-agent-6.2.1/docs/html/_static/ajax-loader.gif
# x datarobot-mlops-agent-6.2.1/docs/html/_static/underscore.js
# x datarobot-mlops-agent-6.2.1/docs/html/_static/websupport.js
# x datarobot-mlops-agent-6.2.1/docs/html/_static/comment-bright.png
# x datarobot-mlops-agent-6.2.1/docs/html/_static/underscore-1.3.1.js
# x datarobot-mlops-agent-6.2.1/docs/html/_static/comment.png
# x datarobot-mlops-agent-6.2.1/docs/html/_static/jquery.js
# x datarobot-mlops-agent-6.2.1/docs/html/spark_monitoring_use_case.html
# x datarobot-mlops-agent-6.2.1/docs/html/_images/
# x datarobot-mlops-agent-6.2.1/docs/html/_images/HowItWorks.png
# x datarobot-mlops-agent-6.2.1/docs/html/mlops_r.html
# x datarobot-mlops-agent-6.2.1/docs/html/java_installation.html
# x datarobot-mlops-agent-6.2.1/docs/html/mlops_lib.html
# x datarobot-mlops-agent-6.2.1/docs/html/java_api.html
# x datarobot-mlops-agent-6.2.1/docs/html/index.html
# x datarobot-mlops-agent-6.2.1/docs/html/agent_installation.html
# x datarobot-mlops-agent-6.2.1/docs/html/mlops_java.html
# x datarobot-mlops-agent-6.2.1/docs/html/mlops_client.html
# x datarobot-mlops-agent-6.2.1/docs/html/examples.html
# x datarobot-mlops-agent-6.2.1/docs/html/_downloads/
# x datarobot-mlops-agent-6.2.1/docs/html/_downloads/datarobot_mlops.pdf
# x datarobot-mlops-agent-6.2.1/docs/html/agent.html
# x datarobot-mlops-agent-6.2.1/docs/html/search.html
# x datarobot-mlops-agent-6.2.1/docs/html/release_notes.html
# x datarobot-mlops-agent-6.2.1/docs/html/python_installation.html
# x datarobot-mlops-agent-6.2.1/docs/html/create_deployment.html
# x datarobot-mlops-agent-6.2.1/docs/html/.buildinfo
# /Users/matthew.cohen/Documents/DR/MLOps/_Agent_example/datarobot-mlops-agent-6.2.1

# %% [markdown]
# ####  To see the file structure...

# %%
# !ls -l
# Out:
# total 64
# -rw-r--r--@  1 matthew.cohen  staff   1816 Aug  4 09:06 LICENSE.txt
# -rw-r--r--@  1 matthew.cohen  staff   1624 Aug  4 09:06 README.md
# -rw-r--r--   1 matthew.cohen  staff  23927 Aug 12 06:52 actuals.csv
# drwxr-xr-x@  9 matthew.cohen  staff    288 Aug 12 06:52 bin
# drwxr-xr-x@  3 matthew.cohen  staff     96 Aug  4 09:06 bosun_plugins
# drwxr-xr-x@  8 matthew.cohen  staff    256 Aug 11 17:25 conf
# drwxr-xr-x@  3 matthew.cohen  staff     96 Aug  4 09:06 docs
# drwxr-xr-x@ 11 matthew.cohen  staff    352 Aug  4 09:06 examples
# drwxr-xr-x@  6 matthew.cohen  staff    192 Aug  4 09:06 lib
# drwxr-xr-x@  5 matthew.cohen  staff    160 Aug 11 17:26 logs
# drwxr-xr-x@  7 matthew.cohen  staff    224 Aug  4 09:06 tools

# %% [markdown]
# #### Install dependency libraries

# %%
# !pip install lib/datarobot_mlops-6.2.1-py2.py3-none-any.whl ##If you have a newer version of the agent, this could be different filename
# Out:
# Requirement already satisfied: datarobot-mlops==6.2.1 from file:///Users/matthew.cohen/Documents/DR/MLOps/_Agent_example/datarobot-mlops-agent-6.2.1/lib/datarobot_mlops-6.2.1-py2.py3-none-any.whl in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (6.2.1)
# Requirement already satisfied: requests in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot-mlops==6.2.1) (2.23.0)
# Requirement already satisfied: py4j==0.10.9 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot-mlops==6.2.1) (0.10.9)
# Requirement already satisfied: setuptools in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot-mlops==6.2.1) (46.1.3)
# Requirement already satisfied: pika==0.13.1 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot-mlops==6.2.1) (0.13.1)
# Requirement already satisfied: boto3==1.11.4 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot-mlops==6.2.1) (1.11.4)
# Requirement already satisfied: google-cloud-pubsub==1.7.0 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot-mlops==6.2.1) (1.7.0)
# Requirement already satisfied: botocore==1.14.4 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot-mlops==6.2.1) (1.14.4)
# Requirement already satisfied: future in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot-mlops==6.2.1) (0.18.2)
# Requirement already satisfied: datarobot in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot-mlops==6.2.1) (2.20.2)
# Requirement already satisfied: pandas in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot-mlops==6.2.1) (0.24.2)
# Requirement already satisfied: python-dateutil in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot-mlops==6.2.1) (2.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from requests->datarobot-mlops==6.2.1) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from requests->datarobot-mlops==6.2.1) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from requests->datarobot-mlops==6.2.1) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from requests->datarobot-mlops==6.2.1) (3.0.4)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from boto3==1.11.4->datarobot-mlops==6.2.1) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from boto3==1.11.4->datarobot-mlops==6.2.1) (0.10.0)
# Requirement already satisfied: google-api-core[grpc]!=1.17.*,!=1.18.*,!=1.19.*,>=1.14.0 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from google-cloud-pubsub==1.7.0->datarobot-mlops==6.2.1) (1.22.0)
# Requirement already satisfied: grpc-google-iam-v1<0.13dev,>=0.12.3 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from google-cloud-pubsub==1.7.0->datarobot-mlops==6.2.1) (0.12.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from botocore==1.14.4->datarobot-mlops==6.2.1) (0.15.2)
# Requirement already satisfied: pyyaml>=3.11 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot->datarobot-mlops==6.2.1) (5.2)
# Requirement already satisfied: attrs<20.0,>=19.1.0 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot->datarobot-mlops==6.2.1) (19.3.0)
# Requirement already satisfied: requests-toolbelt>=0.6 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot->datarobot-mlops==6.2.1) (0.9.1)
# Requirement already satisfied: trafaret!=1.1.0,<2.0,>=0.7 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from datarobot->datarobot-mlops==6.2.1) (1.2.0)
# Requirement already satisfied: pytz>=2011k in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from pandas->datarobot-mlops==6.2.1) (2020.1)
# Requirement already satisfied: numpy>=1.12.0 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from pandas->datarobot-mlops==6.2.1) (1.19.0)
# Requirement already satisfied: six>=1.5 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil->datarobot-mlops==6.2.1) (1.14.0)
# Requirement already satisfied: protobuf>=3.12.0 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from google-api-core[grpc]!=1.17.*,!=1.18.*,!=1.19.*,>=1.14.0->google-cloud-pubsub==1.7.0->datarobot-mlops==6.2.1) (3.12.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from google-api-core[grpc]!=1.17.*,!=1.18.*,!=1.19.*,>=1.14.0->google-cloud-pubsub==1.7.0->datarobot-mlops==6.2.1) (1.52.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.19.1 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from google-api-core[grpc]!=1.17.*,!=1.18.*,!=1.19.*,>=1.14.0->google-cloud-pubsub==1.7.0->datarobot-mlops==6.2.1) (1.20.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.29.0; extra == "grpc" in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from google-api-core[grpc]!=1.17.*,!=1.18.*,!=1.19.*,>=1.14.0->google-cloud-pubsub==1.7.0->datarobot-mlops==6.2.1) (1.31.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.19.1->google-api-core[grpc]!=1.17.*,!=1.18.*,!=1.19.*,>=1.14.0->google-cloud-pubsub==1.7.0->datarobot-mlops==6.2.1) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.19.1->google-api-core[grpc]!=1.17.*,!=1.18.*,!=1.19.*,>=1.14.0->google-cloud-pubsub==1.7.0->datarobot-mlops==6.2.1) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.19.1->google-api-core[grpc]!=1.17.*,!=1.18.*,!=1.19.*,>=1.14.0->google-cloud-pubsub==1.7.0->datarobot-mlops==6.2.1) (4.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/matthew.cohen/opt/anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.19.1->google-api-core[grpc]!=1.17.*,!=1.18.*,!=1.19.*,>=1.14.0->google-cloud-pubsub==1.7.0->datarobot-mlops==6.2.1) (0.4.8)
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/Users/matthew.cohen/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# #### Open Quick Start
#
# As noted in comment code from the Deployment Integrations tab above, open to get started with the agent software configuration steps:
#
# .../{agent install dir}/docs/html/quickstart.html

# %% [markdown]
# #### Edit  .../{agent install dir}/conf/mlops.agent.conf.yaml to have this (everything else can stay as default if you want)
#
# This file is contains the properties used by the MLOps service.  Namely, the DataRobpt host url, your authentication token, the spool to use queue data to send to MLOps.

# %%
"""
# Set your DR host:
mlopsURL: "https://app.datarobot.com"
    
# Set your API token
apiToken: "NWQ1NDA3ZTdmNTU1Y2Q......"

# Create the spool directory on your system that you want MLOps to use, eg /tmp/ta
channelConfigs:
  - type: "FS_SPOOL"
    details: {name: "bench", spoolDirectoryPath: "/tmp/ta"}
"""
# !mkdir /tmp/ta
# Out:
# mkdir: /tmp/ta: File exists

# %% [markdown]
# #### Commands to get you started
#
# This will allow you to start, get status, and stop the MLOps agent service. You will only need to run start for now.  Run status if you want to check on the service.

# %%
# Start
# !./bin/start-agent.sh
# Out:
# INFO: AGENT_CONFIG_YAML=/Users/matthew.cohen/Documents/DR/MLOps/_Agent_example/datarobot-mlops-agent-6.2.1/conf/mlops.agent.conf.yaml
# INFO: AGENT_LOG_PROPERTIES=/Users/matthew.cohen/Documents/DR/MLOps/_Agent_example/datarobot-mlops-agent-6.2.1/conf/mlops.log4j2.properties
# INFO: AGENT_JVM_OPT=-Xmx1G
# INFO: AGENT_JAR_PATH=/Users/matthew.cohen/Documents/DR/MLOps/_Agent_example/datarobot-mlops-agent-6.2.1/lib/mlops-agent-6.2.1.jar
# INFO: AGENT_LOG_PATH=/Users/matthew.cohen/Documents/DR/MLOps/_Agent_example/datarobot-mlops-agent-6.2.1/logs/mlops.agent.log
#
# Starting MLOps-Agent
#
#
# DataRobot MLOps-Agent is running.

# %%
# Get Status
# !./bin/status-agent.sh
# Out:
# DataRobot MLOps-Agent is running as a service.

# %%
# Shutdown - DON'T RUN THIS CELL, IT'S JUST SHOWING YOU HOW TO SHUTDOWN
# !./bin/stop-agent.sh

# %% [markdown]
# ## Create an MLOps Model Package for a model and deploy it

# %% [markdown]
# #### Train a simple RandomForestClassifier model to use for this example

# %%
# Change the notebook shell working directory to the instal location.
# %cd /usr/local/opt/datarobot-mlops-agent-6.1.3

import pandas as pd
import numpy as np
import time
import csv
import pytz
import json
import yaml
import datetime
from sklearn.ensemble import RandomForestClassifier

TRAINING_DATA = './examples/data/surgical-dataset.csv'

df = pd.read_csv(TRAINING_DATA)

columns = list(df.columns)
arr = df.to_numpy()

np.random.shuffle(arr)

split_ratio = 0.8
prediction_threshold = 0.5

train_data_len = int(arr.shape[0] * split_ratio)

train_data = arr[:train_data_len, :-1]
label = arr[:train_data_len, -1]
test_data = arr[train_data_len:, :-1]
test_df = df[train_data_len:]

# train the model
clf = RandomForestClassifier(n_estimators=10, max_depth=2, random_state=0)
clf.fit(train_data, label)
# Out:
# RandomForestClassifier(max_depth=2, n_estimators=10, random_state=0)

# %% [markdown]
# #### Using the MLOps client, create a new model package to represent the random forest model we just created.  This includes uploading the traning data and enabling data drift.

# %%
from datarobot.mlops.mlops import MLOps
from datarobot.mlops.common.enums import OutputType
from datarobot.mlops.connected.client import MLOpsClient
from datarobot.mlops.common.exception import DRConnectedException
from datarobot.mlops.constants import Constants

# Read the model configuration info from the example.  This is used to create the model package.
with open('examples/model_config/surgical_binary_classification.json', "r") as f:
    model_info = json.loads(f.read())
model_info

# Read the mlops connection info from the provided example 
with open('./conf/mlops.agent.conf.yaml') as file:
    # The FullLoader parameter handles the conversion from YAML
    # scalar values to Python the dictionary format
    agent_yaml_dict = yaml.load(file, Loader=yaml.FullLoader)

MLOPS_URL = agent_yaml_dict['mlopsURL']
API_TOKEN = agent_yaml_dict['apiToken']

# Create connected client
mlops_connected_client = MLOpsClient(MLOPS_URL, API_TOKEN)

# Add training_data to model configuration
print("Uploading training data - {}. This may take some time...".format(TRAINING_DATA))
dataset_id = mlops_connected_client.upload_dataset(TRAINING_DATA)
print("Training dataset uploaded. Catalog ID {}.".format(dataset_id))
model_info["datasets"] = {"trainingDataCatalogId": dataset_id}

# Create the model package
print('Create model package')
model_pkg_id = mlops_connected_client.create_model_package(model_info)
model_pkg = mlops_connected_client.get_model_package(model_pkg_id)
model_id = model_pkg["modelId"]

# Deploy the model package
print('Deploy model package')

# Give the deployment a name:
DEPLOYMENT_NAME="Python binary classification remote model " + str(datetime.datetime.now())

deployment_id = mlops_connected_client.deploy_model_package(model_pkg["id"],
                                                            DEPLOYMENT_NAME)

# Enable data drift tracking
print('Enable feature drift')
enable_feature_drift = TRAINING_DATA is not None
mlops_connected_client.update_deployment_settings(deployment_id, target_drift=True,
                                                  feature_drift=enable_feature_drift)
_ = mlops_connected_client.get_deployment_settings(deployment_id)

print("\nDone.")
print("DEPLOYMENT_ID=%s, MODEL_ID=%s" % (deployment_id, model_id))

DEPLOYMENT_ID = deployment_id
MODEL_ID = model_id
# Out:
# Uploading training data - ./examples/data/surgical-dataset.csv. This may take some time...
# Training dataset uploaded. Catalog ID 5f33fb45fa5ce90daaa8bc40.
# Create model package
# Deploy model package
# Enable feature drift
#
# Done.
# DEPLOYMENT_ID=5f33fb6a735d1f1236a97347, MODEL_ID=5f33fb6899bcc941e5d28050

# %% [markdown]
# ## Run Model Predictions
#
# #### Call the external model's predict fuction and send prediction data to MLOps

# %%
#
# This can code be found on:
# 1. under the Integrtation tab for your depoyment in DataRobot MLOps, or in
# 2. the agent example code on your filesystem in ./examples/python/ and ./tools/
#    This example is from BinaryClassificationExample
#
CLASS_NAMES = ['1', "0"]
OUTPUT_TYPE = OutputType.OUTPUT_DIR

# Spool directory path must match the Monitoring Agent path configured by admin.
SPOOL_DIR = "/tmp/ta"
SPOOL_MAX_FILE_SIZE = 104857600
SPOOL_MAX_FILES = 5

ACTUALS_OUTPUT_FILE = "actuals.csv"
               
def process_predictions(deployment_id, model_id, output_type, spool_dir, spool_max_file_size, spool_max_files, class_names):
    """
    This is a binary classification algorithm example.
    User can call the DataRobot MLOps library functions to report statistics.
    """

    # Get predictions
    start_time = time.time()
    predictions = clf.predict_proba(test_data).tolist()
    num_predictions = len(predictions)
    end_time = time.time()
    
    # Get assocation id's for the predictions so we can track them with the actuals
    def _generate_unique_association_ids(num_samples):
        ts = time.time()
        return ["x_{}_{}".format(ts, i) for i in range(num_samples)]
    association_ids = _generate_unique_association_ids(len(test_data))

    # MLOPS: initialize the MLOps instance
    print("Get an MLOps instance")
    mlops = MLOps() \
        .set_deployment_id(deployment_id) \
        .set_model_id(model_id) \
        .set_output_type(output_type) \
        .set_spool_dir(spool_dir) \
        .set_spool_file_max_size(spool_max_file_size) \
        .set_spool_max_files(spool_max_files) \
        .init()

    # MLOPS: report the number of predictions in the request and the execution time.
    print("Send MLOps deployment stats")
    mlops.report_deployment_stats(num_predictions, end_time - start_time)

    # MLOPS: report the predictions data: features, predictions, class_names
    print("Send MLOps prediction data")
    mlops.report_predictions_data(features_df=test_df, 
                                  predictions=predictions, 
                                  class_names=class_names,
                                  association_ids=association_ids)
    
    target_column_name = columns[len(columns) - 1]
    target_values = []
    orig_labels = test_df[target_column_name].tolist()
    
    print("Wrote actuals file: %s" % ACTUALS_OUTPUT_FILE)
    def write_actuals_file(out_filename, test_data_labels, association_ids):
        """
         Generate a CSV file with the association ids and labels, this example
         uses a dataset that has labels already.
         In a real use case actuals (labels) will show after prediction is done.

        :param out_filename:      name of csv file
        :param test_data_labels:  actual values (labels)
        :param association_ids:   association id list used for predictions
        """
        with open(out_filename, mode="w") as actuals_csv_file:
            writer = csv.writer(actuals_csv_file, delimiter=",")
            writer.writerow(
                [
                    Constants.ACTUALS_ASSOCIATION_ID_KEY,
                    Constants.ACTUALS_VALUE_KEY,
                    Constants.ACTUALS_TIMESTAMP_KEY
                ]
            )
            tz = pytz.timezone("America/Los_Angeles")
            for (association_id, label) in zip(association_ids, test_data_labels):
                actual_timestamp = datetime.datetime.now().replace(tzinfo=tz).isoformat()
                writer.writerow([association_id, "1" if label else "0", actual_timestamp])

        
    # Write csv file with labels and association Id, when output file is provided
    write_actuals_file(ACTUALS_OUTPUT_FILE, orig_labels, association_ids)

    # MLOPS: release MLOps resources when finished.
    mlops.shutdown()

    print("Done.")

process_predictions(DEPLOYMENT_ID, MODEL_ID, OUTPUT_TYPE, SPOOL_DIR, SPOOL_MAX_FILE_SIZE, SPOOL_MAX_FILES, CLASS_NAMES)
# Out:
# Get an MLOps instance
# Send MLOps deployment stats
# Send MLOps prediction data
# Wrote actuals file: actuals.csv
# Done.

# %% [markdown]
# ### Upload actuals back to MLOps

# %%
def _get_correct_actual_value(deployment_type, value):
    if deployment_type == "Regression":
        return float(value)
    return str(value)


def _get_correct_flag_value(value_str):
    if value_str == "True":
        return True
    return False
    
def upload_actuals():
    print("Connect MLOps client")
    mlops_connected_client = MLOpsClient(MLOPS_URL, API_TOKEN)
    deployment_type = mlops_connected_client.get_deployment_type(DEPLOYMENT_ID)

    actuals = []
    with open(ACTUALS_OUTPUT_FILE, mode="r") as actuals_csv_file:
        reader = csv.DictReader(actuals_csv_file)
        for row in reader:
            actual = {}
            for key, value in row.items():
                if key == Constants.ACTUALS_WAS_ACTED_ON_KEY:
                    value = _get_correct_flag_value(value)
                if key == Constants.ACTUALS_VALUE_KEY:
                    value = _get_correct_actual_value(deployment_type, value)
                actual[key] = value
            actuals.append(actual)

            if len(actuals) == 10000:
                mlops_connected_client.submit_actuals(DEPLOYMENT_ID, actuals)
                actuals = []

    # Submit the actuals
    print("Submit actuals")
    mlops_connected_client.submit_actuals(DEPLOYMENT_ID, actuals)
    
    print("Done.")    

upload_actuals()
# Out:
# Connect MLOps client
# Submit actuals
# Done.

# %% [markdown]
# ### Stop the mlops service

# %%
# !bin/stop-agent.sh
# Out:
# DataRobot MLOps-Agent shutdown done.
