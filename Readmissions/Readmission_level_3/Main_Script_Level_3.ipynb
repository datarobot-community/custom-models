# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.impute import SimpleImputer
import joblib

from keras.layers import Dense, Dropout
from keras.models import Model, Sequential
from keras.wrappers.scikit_learn import KerasClassifier

# %% [markdown]
# ### Import Data

# %%
train = pd.read_csv('../data/readmissions_train.csv')
train.drop(['diag_1_desc','diag_2_desc','diag_3_desc'],axis=1,inplace=True)

X = train.drop('readmitted',axis=1)
y = train.pop('readmitted')

# %% [markdown]
# ### Function for Keras Model

# %%
#First I define my keras model

def create_model():
    optimizer='adagrad'
    kernel_initializer='glorot_uniform'
    dropout=0.2
    
    model = Sequential()
    model.add(Dense(64,activation='relu',kernel_initializer=kernel_initializer))
    model.add(Dropout(dropout))
    model.add(Dense(1,activation='sigmoid',kernel_initializer=kernel_initializer))

    model.compile(loss='binary_crossentropy',optimizer=optimizer, metrics=['accuracy'])

    return model

# %% [markdown]
# ### Define Preprocessing step per type of column

# %%
#Preprocessing for numerical features
numeric_features = list(set(X.columns) - set(list(X.select_dtypes('object').columns)))
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

#Preprocessing for categorical features
categorical_features = list(train.select_dtypes('object').columns)
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

#Preprocessor with all of the steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %% [markdown]
# ### Fit the Preprocessing Pipeline

# %%
# Full preprocessing pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

#Train the model-Pipeline
pipeline.fit(X,y)

#Preprocess x
preprocessed = pipeline.transform(X)

# %% [markdown]
# ### Train the Keras Classifier

# %%
#Create the keras model
clf = KerasClassifier(build_fn=create_model, verbose=0)
clf.fit(preprocessed,y)

# %% [markdown]
# ### Save Custom Model files

# %%
joblib.dump(pipeline,'custom_model/preprocessing.pkl')
clf.model.save('custom_model/model.h5')

# %% [markdown]
# ### Verify custom model integrity with DRUM

# %%
# !drum validation --code-dir ./custom_model --input ../data/readmissions_test.csv --target-type binary --positive-class-label yes --negative-class-label no
# Out:
#  0.411341
#
# [500 rows x 2 columns]
# 2020-10-23 18:43:51.065199: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-10-23 18:43:51.079357: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f90b85ec670 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-23 18:43:51.079393: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-23 18:43:51,869 WARNING tensorflow:  From /Users/thodoris.petropoulos/Downloads/Custom Model Examples/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.513239  0.486761
# 1    0.537295  0.462705
# 2    0.568742  0.431258
# 3    0.517759  0.482241
# 4    0.519673  0.480327
# ..        ...       ...
# 495  0.508103  0.491897
# 496  0.535579  0.464421
# 497  0.575813  0.424187
# 498  0.667106  0.332894
# 499  0.585550  0.414450
#
# [500 rows x 2 columns]
# 2020-10-23 18:43:55.762517: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-10-23 18:43:55.775997: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fe84c577410 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-23 18:43:55.776032: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-23 18:43:56,549 WARNING tensorflow:  From /Users/thodoris.petropoulos/Downloads/Custom Model Examples/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.517224  0.482776
# 1    0.543022  0.456978
# 2    0.568938  0.431062
# 3    0.526573  0.473427
# 4    0.525445  0.474555
# ..        ...       ...
# 495  0.515034  0.484966
# 496  0.532431  0.467569
# 497  0.576864  0.423136
# 498  0.676826  0.323174
# 499  0.586656  0.413344
#
# [500 rows x 2 columns]
# 2020-10-23 18:44:00.482625: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-10-23 18:44:00.496494: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f9aad9ced30 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-23 18:44:00.496527: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-23 18:44:01,268 WARNING tensorflow:  From /Users/thodoris.petropoulos/Downloads/Custom Model Examples/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.509090  0.490910
# 1    0.535017  0.464983
# 2    0.562212  0.437788
# 3    0.515802  0.484198
# 4    0.517304  0.482696
# ..        ...       ...
# 495  0.503194  0.496806
# 496  0.527213  0.472787
# 497  0.572193  0.427807
# 498  0.662976  0.337024
# 499  0.577472  0.422528
#
# [500 rows x 2 columns]
# 2020-10-23 18:44:05.194905: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-10-23 18:44:05.209211: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fae32af5690 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-23 18:44:05.209259: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-23 18:44:05,972 WARNING tensorflow:  From /Users/thodoris.petropoulos/Downloads/Custom Model Examples/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.506943  0.493057
# 1    0.532472  0.467528
# 2    0.561579  0.438421
# 3    0.515089  0.484911
# 4    0.518543  0.481457
# ..        ...       ...
# 495  0.508293  0.491707
# 496  0.527307  0.472693
# 497  0.572933  0.427067
# 498  0.662741  0.337259
# 499  0.578518  0.421482
#
# [500 rows x 2 columns]
# 2020-10-23 18:44:09.939387: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-10-23 18:44:09.954847: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f8b9c897090 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-23 18:44:09.954888: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-23 18:44:10,702 WARNING tensorflow:  From /Users/thodoris.petropoulos/Downloads/Custom Model Examples/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0.504812  0.495188
# 1    0.530814  0.469186
# 2    0.563027  0.436973
# 3    0.515688  0.484312
# 4    0.516842  0.483158
# ..        ...       ...
# 495  0.503764  0.496236
# 496  0.525214  0.474786
# 497  0.571084  0.428916
# 498  0.665340  0.334660
# 499  0.577952  0.422048
#
# [500 rows x 2 columns]
# 2020-10-23 18:44:14.728026: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-10-23 18:44:14.741672: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7faeed1e4740 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-23 18:44:14.741706: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-23 18:44:15,514 WARNING tensorflow:  From /Users/thodoris.petropoulos/Downloads/Custom Model Examples/Readmission_level_3/custom_model/custom.py:52: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
#           yes        no
# 0    0